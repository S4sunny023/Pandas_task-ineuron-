# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"E:\Downloads\AgentPerformance.csv")

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df1["converted_Date"]= pd.to_datetime(df1["Date"])

# %%
df1.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback converted_Date
# 0                 0:04:20            4.11               9     2022-07-30
# 1                 0:28:25            3.14               7     2022-07-30

# %%
df1['converted_week']=df1['converted_Date'].dt.isocalendar().week

# %%
df1['converted_days']=df1['converted_Date'].dt.day

# %%
df1_mean=df1.groupby(['Agent Name','converted_week'])['Average Rating'].mean().to_frame()

# %%
df1_mean
# Out:
#                            Average Rating
# Agent Name converted_week
# Abhishek   26                    0.000000
#            27                    0.000000
#            28                    0.000000
#            29                    0.000000
#            30                    0.000000
# ...                                   ...
# Zeeshan    26                    0.000000
#            27                    1.307143
#            28                    2.948571
#            29                    3.180000
#            30                    2.760000
#
# [350 rows x 1 columns]

# %%
df1.groupby("Agent Name")['converted_days'].count().sort_values()
# Out:
# Agent Name
# Abhishek              30
# Mukesh                30
# Mukesh Rao            30
# Muskan Garg           30
# Nandani Gupta         30
#                       ..
# Harikrishnan Shaji    30
# Deepranjan Gupta      30
# Zeeshan               30
# Rishav Dash           60
# Ashish                60
# Name: converted_days, Length: 70, dtype: int64

# %%
df1.groupby('Agent Name')['Total Chats'].sum().to_frame()
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %%
df1.groupby("Agent Name")['Total Feedback'].sum().to_frame()
# Out:
#                Total Feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %%
df1[(df1["Average Rating"]>3.5)&(df1["Average Rating"]<4)]["Agent Name"].to_frame()
# Out:
#                Agent Name
# 4                  Swati
# 10           Manjunatha A
# 76          Prateek _iot
# 78          Nandani Gupta
# 80          Jaydeep Dixit
# ...                   ...
# 1869  Boktiar Ahmed Bappy
# 1874        Ayushi Mishra
# 1941       Jawala Prakash
# 2021        Aditya Shinde
# 2023     Deepranjan Gupta
#
# [78 rows x 1 columns]

# %%
df1[df1["Average Rating"]<3.5]["Agent Name"].to_frame()
# Out:
#               Agent Name
# 1          Nandani Gupta
# 19      Hitesh Choudhary
# 20            Sanjeevan
# 21              Anirudh
# 22      Shiva Srivastava
# ...                  ...
# 2155   Sowmiya Sivakumar
# 2156             Nitin M
# 2157              Vivek
# 2158       Ayushi Mishra
# 2159  Chaitra K Hiremath
#
# [1474 rows x 1 columns]

# %%
df1[df1["Average Rating"]>4.5]["Agent Name"].to_frame()
# Out:
#               Agent Name
# 2             Ameya Jain
# 3          Mahesh Sarade
# 5                Mukesh
# 6        Saikumarreddy N
# 7          Sanjeev Kumar
# ...                  ...
# 2100      Shubham Sharma
# 2101       Jaydeep Dixit
# 2102  Shivananda Sonwane
# 2103      Khushboo Priya
# 2104     Hrisikesh Neogi
#
# [307 rows x 1 columns]

# %%
df1.groupby("Agent Name")["Total Feedback"].mean()>4.5
# Out:
# Agent Name
# Abhishek         False
# Aditya           False
# Aditya Shinde     True
# Aditya_iot       False
# Amersh           False
#                  ...
# Uday Mishra      False
# Vasanth P        False
# Vivek            False
# Wasim             True
# Zeeshan           True
# Name: Total Feedback, Length: 70, dtype: bool

# %%
df1.groupby("Average Response Time")["Agent Name"]

# %%
df1.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback converted_Date  \
# 0                 0:04:20            4.11               9     2022-07-30
# 1                 0:28:25            3.14               7     2022-07-30
# 2                 0:11:36            4.55              11     2022-07-30
# 3                 0:15:46            4.71               7     2022-07-30
# 4                 0:16:33            3.67               6     2022-07-30
#
#    converted_week  converted_days
# 0              30              30
# 1              30              30
# ...

# %%
def get_sec(time_str):
    hh,mm,ss = time_str.split(":")
    return int(hh)*3600+int(mm)*60 + int(ss)

# %%
avg_response_sec= []
for i in df1["Average Response Time"]:
    avg_response_sec.append(get_sec(i))
avg_response_sec
df1["avg_response_sec"] = avg_response_sec

# %%
df1.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback converted_Date  \
# 0                 0:04:20            4.11               9     2022-07-30
# 1                 0:28:25            3.14               7     2022-07-30
# 2                 0:11:36            4.55              11     2022-07-30
# 3                 0:15:46            4.71               7     2022-07-30
# 4                 0:16:33            3.67               6     2022-07-30
#
#    converted_week  converted_days  avg_response_sec
# 0              30              30                38
# ...

# %%
df1.groupby(["Agent Name","converted_week"])["avg_response_sec"].mean().to_frame()
# Out:
#                            avg_response_sec
# Agent Name converted_week
# Abhishek   26                      0.000000
#            27                      0.000000
#            28                      0.000000
#            29                      0.000000
#            30                      0.000000
# ...                                     ...
# Zeeshan    26                      0.000000
#            27                     23.571429
#            28                    123.428571
#            29                     62.857143
#            30                     63.833333
#
# [350 rows x 1 columns]

# %%
df.groupby([""])

# %%
avg_resolution_time = []
for j in df1["Average Resolution Time"]:
    avg_resolution_time.append(get_sec(i))
    
df1['avg_resolution_time'] = avg_resolution_time

# %%
df1.groupby(["Agent Name","converted_week"])["avg_resolution_time"].mean().to_frame()
# Out:
#                            avg_resolution_time
# Agent Name converted_week
# Abhishek   26                              0.0
#            27                              0.0
#            28                              0.0
#            29                              0.0
#            30                              0.0
# ...                                        ...
# Zeeshan    26                              0.0
#            27                              0.0
#            28                              0.0
#            29                              0.0
#            30                              0.0
#
# [350 rows x 1 columns]

# %%
list(df1["Agent Name"])
# Out:
# ['Prerna Singh',
#  'Nandani Gupta',
#  'Ameya Jain',
#  'Mahesh Sarade',
#  'Swati ',
#  'Mukesh ',
#  'Saikumarreddy N',
#  'Sanjeev Kumar',
#  'Shubham Sharma',
#  'Nishtha Jain',
#  'Manjunatha A',
#  'Khushboo Priya',
#  'Suraj S Bilgi',
#  'Harikrishnan Shaji',
#  'Hrisikesh Neogi',
#  'Shivan K',
#  'Sowmiya Sivakumar',
#  'Madhulika G',
#  'Mithun S',
#  'Hitesh Choudhary',
#  'Sanjeevan ',
#  'Anirudh ',
#  'Shiva Srivastava',
#  'Dibyanshu ',
#  'Ashish ',
#  'Uday Mishra',
#  'Aditya Shinde',
#  'Jayant Kumar',
#  'Aditya_iot ',
#  'Prabir Kumar Satapathy',
#  'Saurabh Shukla',
#  'Wasim ',
#  'Samprit ',
#  'Maitry ',
#  'Abhishek ',
#  'Rishav Dash',
#  'Aravind ',
#  'Tarun ',
#  'Muskan Garg',
#  'Ankit Sharma',
#  'Bharath ',
#  'Ashad Nasim',
#  'Vasanth P',
#  'Aditya ',
#  'Amersh ',
#  'Sandipan Saha',
#  'Ineuron Intelligence ',
#  'Mahak ',
#  'Mukesh Rao ',
#  'Zeeshan ',
#  'Rishav Dash',
#  'Anurag Tiwari',
#  'Ankitjha ',
#  'Saif Khan',
#  'Jaydeep Dixit',
# ...

# %%
df1.groupby(["Agent Name","Total Chats"])["Total Feedback"].sum()
# Out:
# Agent Name     Total Chats
# Abhishek       0               0
# Aditya         0               0
# Aditya Shinde  0               0
#                8               7
#                14              9
#                               ..
# Zeeshan        36             28
#                37             25
#                41             25
#                46             28
#                92             35
# Name: Total Feedback, Length: 638, dtype: int64

# %%
df1.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback converted_Date  \
# 0                 0:04:20            4.11               9     2022-07-30
# 1                 0:28:25            3.14               7     2022-07-30
# 2                 0:11:36            4.55              11     2022-07-30
# 3                 0:15:46            4.71               7     2022-07-30
# 4                 0:16:33            3.67               6     2022-07-30
#
#    converted_week  converted_days  avg_response_sec  avg_resolution_time
# ...

# %%
df2 = pd.read_csv(r"E:\Downloads\AgentLogingReport.csv")

# %%
df2.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36

# %%
df2["converted_date"] = pd.to_datetime(df2["Date"])

# %%
df2.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
#
#   converted_date
# 0     2022-07-30
# 1     2022-07-30
# 2     2022-07-30
# 3     2022-07-30
# 4     2022-07-30

# %%
df2["converted_week"]= df2['converted_date'].dt.isocalendar().week

# %%
df2["converted_day"] = df2["converted_date"].dt.day

# %%
df2.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
#
#   converted_date  converted_week  converted_day  Total_duration_sec
# 0     2022-07-30              30             30                7450
# 1     2022-07-30              30             30                  17
# 2     2022-07-30              30             30                8802
# 3     2022-07-30              30             30                2706
# 4     2022-07-30              30             30                4116

# %%
Total_duration_sec = []
for j in df2["Duration"]:
    Total_duration_sec.append(get_sec(j))
    
df2["Total_duration_sec"] = Total_duration_sec

# %%
df2.groupby(["Agent","converted_week"])["Total_duration_sec"].mean()
# Out:
# Agent          converted_week
# Aditya Shinde  30                1.300000e+02
# Aditya_iot     29                7.314333e+03
#                30                5.781500e+03
# Amersh         30                2.757500e+03
# Ameya Jain     29                1.238557e+04
#                                      ...
# Tarun          26                1.850900e+06
# Wasim          29                7.850222e+03
#                30                9.344818e+03
# Zeeshan        29                1.465650e+04
#                30                2.219500e+04
# Name: Total_duration_sec, Length: 89, dtype: float64

# %%
df2["Month"]= df2["converted_date"].dt.month

# %%
df2.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
#
#   converted_date  converted_week  converted_day  Total_duration_sec  Month
# 0     2022-07-30              30             30                7450      7
# 1     2022-07-30              30             30                  17      7
# 2     2022-07-30              30             30                8802      7
# 3     2022-07-30              30             30                2706      7
# 4     2022-07-30              30             30                4116      7

# %% [markdown]
#  total percentage of active hour for a month

# %%
100*df2["Total_duration_sec"]/df2.groupby(["Month"])["Total_duration_sec"].transform("sum")
# Out:
# 0       0.094930
# 1       0.000217
# 2       0.112158
# 3       0.034481
# 4       0.052447
#          ...
# 995     0.274176
# 996     0.275782
# 997     0.250437
# 998     0.242078
# 999    23.584737
# Name: Total_duration_sec, Length: 1000, dtype: float64
